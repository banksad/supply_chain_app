# %%
import pandas as pd
import plotly.express as px

# %%
df = px.data.tips()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = px.sunburst(df, path=['day', 'time', 'sex'], values='total_bill')
fig.write_html('second_figure.html', auto_open=True)

# %%
iot_use = pd.read_csv('data/iot_cleaned.csv')
imports_use = pd.read_csv('data/imports_use_cleaned.csv')
iot_use.head()
# Out:
#    Unnamed: 0                        domestic input requirements  \
# 0           0  Products of agriculture, hunting and related s...
# 1           1  Products of forestry, logging and related serv...
# 2           2  Fish and other fishing products; aquaculture p...
# 3           3                                   Coal and lignite
# 4           4  Extraction Of Crude Petroleum And Natural Gas ...
#
#                                       output product  value  proportion
# 0  Products of agriculture, hunting and related s...   3198    0.211229
# 1  Products of agriculture, hunting and related s...    114    0.007530
# 2  Products of agriculture, hunting and related s...      0    0.000000
# 3  Products of agriculture, hunting and related s...      0    0.000000
# 4  Products of agriculture, hunting and related s...      0    0.000000

# %%
iot_use['component']='Domestically produced inputs'
imports_use['component']='Imported inputs'

iot_use.rename(columns={'domestic input requirements':'input product'}, inplace=True)
imports_use.rename(columns={'import requirements':'input product'}, inplace=True)

# %%
iot_use.head()
# Out:
#    Unnamed: 0                                      input product  \
# 0           0  Products of agriculture, hunting and related s...
# 1           1  Products of forestry, logging and related serv...
# 2           2  Fish and other fishing products; aquaculture p...
# 3           3                                   Coal and lignite
# 4           4  Extraction Of Crude Petroleum And Natural Gas ...
#
#                                       output product  value  proportion  \
# 0  Products of agriculture, hunting and related s...   3198    0.211229
# 1  Products of agriculture, hunting and related s...    114    0.007530
# 2  Products of agriculture, hunting and related s...      0    0.000000
# 3  Products of agriculture, hunting and related s...      0    0.000000
# 4  Products of agriculture, hunting and related s...      0    0.000000
#
#                       component
# 0  Domestically produced inputs
# 1  Domestically produced inputs
# 2  Domestically produced inputs
# ...

# %%
imports_use.head()
# Out:
#    Unnamed: 0                                      input product  \
# 0           0  Products of agriculture, hunting and related s...
# 1           1  Products of forestry, logging and related serv...
# 2           2  Fish and other fishing products; aquaculture p...
# 3           3                                   Coal and lignite
# 4           4  Extraction Of Crude Petroleum And Natural Gas ...
#
#                                       output product  value  proportion  \
# 0  Products of agriculture, hunting and related s...    443    0.704293
# 1  Products of agriculture, hunting and related s...      1    0.001590
# 2  Products of agriculture, hunting and related s...      0    0.000000
# 3  Products of agriculture, hunting and related s...      0    0.000000
# 4  Products of agriculture, hunting and related s...      0    0.000000
#
#          component
# 0  Imported inputs
# 1  Imported inputs
# 2  Imported inputs
# 3  Imported inputs
# 4  Imported inputs

# %%
combined = pd.concat([imports_use,iot_use])
combined['proportion'] = combined['value'] / combined.groupby('output product')['value'].transform('sum')
combined.head()
# Out:
#    Unnamed: 0                                      input product  \
# 0           0  Products of agriculture, hunting and related s...
# 1           1  Products of forestry, logging and related serv...
# 2           2  Fish and other fishing products; aquaculture p...
# 3           3                                   Coal and lignite
# 4           4  Extraction Of Crude Petroleum And Natural Gas ...
#
#                                       output product  value  proportion  \
# 0  Products of agriculture, hunting and related s...    443    0.028093
# 1  Products of agriculture, hunting and related s...      1    0.000063
# 2  Products of agriculture, hunting and related s...      0    0.000000
# 3  Products of agriculture, hunting and related s...      0    0.000000
# 4  Products of agriculture, hunting and related s...      0    0.000000
#
#          component
# 0  Imported inputs
# 1  Imported inputs
# 2  Imported inputs
# 3  Imported inputs
# 4  Imported inputs

# %%
combined.to_csv('data/combined.csv')
combined.tail()
# Out:
#        Unnamed: 0                                      input product  \
# 11020       11020  Sports services and amusement and recreation s...
# 11021       11021     Services furnished by membership organisations
# 11022       11022  Repair services of computers and personal and ...
# 11023       11023                            Other personal services
# 11024       11024  Services of households as employers of domesti...
#
#                                           output product  value  proportion  \
# 11020  Services of households as employers of domesti...      0         NaN
# 11021  Services of households as employers of domesti...      0         NaN
# 11022  Services of households as employers of domesti...      0         NaN
# 11023  Services of households as employers of domesti...      0         NaN
# 11024  Services of households as employers of domesti...      0         NaN
#
#                           component
# 11020  Domestically produced inputs
# ...

# %%
# Total inputs into furniture products (domestically produced and imported)
total = combined[combined['output product']=='Furniture']['value'].sum()
total
# Out:
# 4510

# %%
fig = px.sunburst(combined_subset, path=['component','input product'], values='value')
fig.write_html('sunburst.html', auto_open=True)
# Out:
# D:\Anaconda\envs\streamlit\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# D:\Anaconda\envs\streamlit\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
