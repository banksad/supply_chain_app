# %%
import pandas as pd
import os


os.getcwd()
# Out:
# '/Users/andrewbanks/Projects/supply_chain_app/notebooks'

# %%
data = pd.read_csv('../data/imports_use_cleaned.csv')
data = data.rename(columns={'import requirements':'input product'})
data['component'] = 'Imported inputs'
data.head()
# Out:
#    Unnamed: 0                                      input product  \
# 0           0  A01 Products of agriculture, hunting and relat...
# 1           1  A02 Products of forestry, logging and related ...
# 2           2  A03 Fish and other fishing products; aquacultu...
# 3           3                               B05 Coal and lignite
# 4           4  B06 & B07 Extraction Of Crude Petroleum And Na...
#
#                                       output product       value  proportion  \
# 0  A01 Products of agriculture, hunting and relat...  443.069136    0.705798
# 1  A01 Products of agriculture, hunting and relat...    0.915296    0.001458
# 2  A01 Products of agriculture, hunting and relat...    0.000000    0.000000
# 3  A01 Products of agriculture, hunting and relat...    0.000000    0.000000
# 4  A01 Products of agriculture, hunting and relat...    0.000000    0.000000
#
#          component
# 0  Imported inputs
# 1  Imported inputs
# 2  Imported inputs
# 3  Imported inputs
# 4  Imported inputs

# %%
data2 = pd.read_csv('../data/iot_cleaned.csv')
data2 = data2.rename(columns={'domestic input requirements':'input product'})
data2['component'] = 'Domestically produced inputs'
data2.head()
# Out:
#    Unnamed: 0                                      input product  \
# 0           0  A01 Products of agriculture, hunting and relat...
# 1           1  A02 Products of forestry, logging and related ...
# 2           2  A03 Fish and other fishing products; aquacultu...
# 3           3                               B05 Coal and lignite
# 4           4  B06 & B07 Extraction Of Crude Petroleum And Na...
#
#                                       output product        value  proportion  \
# 0  A01 Products of agriculture, hunting and relat...  3197.593647    0.211186
# 1  A01 Products of agriculture, hunting and relat...   114.428630    0.007557
# 2  A01 Products of agriculture, hunting and relat...     0.000000    0.000000
# 3  A01 Products of agriculture, hunting and relat...     0.000000    0.000000
# 4  A01 Products of agriculture, hunting and relat...     0.000000    0.000000
#
#                       component
# 0  Domestically produced inputs
# 1  Domestically produced inputs
# 2  Domestically produced inputs
# 3  Domestically produced inputs
# 4  Domestically produced inputs

# %%
data3 = pd.concat([data,data2])
data3['proportion_total']= data3['value'] / data3.groupby('output product')['value'].transform('sum')
data3.head()
# Out:
#    Unnamed: 0                                      input product  \
# 0           0  A01 Products of agriculture, hunting and relat...
# 1           1  A02 Products of forestry, logging and related ...
# 2           2  A03 Fish and other fishing products; aquacultu...
# 3           3                               B05 Coal and lignite
# 4           4  B06 & B07 Extraction Of Crude Petroleum And Na...
#
#                                       output product       value  proportion  \
# 0  A01 Products of agriculture, hunting and relat...  443.069136    0.705798
# 1  A01 Products of agriculture, hunting and relat...    0.915296    0.001458
# 2  A01 Products of agriculture, hunting and relat...    0.000000    0.000000
# 3  A01 Products of agriculture, hunting and relat...    0.000000    0.000000
# 4  A01 Products of agriculture, hunting and relat...    0.000000    0.000000
#
#          component  proportion_total
# 0  Imported inputs          0.028098
# 1  Imported inputs          0.000058
# 2  Imported inputs          0.000000
# 3  Imported inputs          0.000000
# 4  Imported inputs          0.000000

# %%
data3[data3['output product'].str.startswith('A01')].sort_values(by='value')
# Out:
#      Unnamed: 0                                      input product  \
# 103         103                        S96 Other personal services
# 18           18                                C14 Wearing apparel
# 17           17                                       C13 Textiles
# 16           16                                  C1107 Soft drinks
# 15           15  C11.01-6 & C12 Alcoholic beverages  & Tobacco ...
# ..          ...                                                ...
# 73           73  K64 Financial services, except insurance and p...
# 14           14                         C109 Prepared animal feeds
# 29           29          C20C Dyestuffs, agro-chemicals - 20.12/20
# 58           58  G46 Wholesale trade services, except of motor ...
# 0             0  A01 Products of agriculture, hunting and relat...
#
#                                         output product        value  \
# 103  A01 Products of agriculture, hunting and relat...     0.000000
# 18   A01 Products of agriculture, hunting and relat...     0.000000
# 17   A01 Products of agriculture, hunting and relat...     0.000000
# 16   A01 Products of agriculture, hunting and relat...     0.000000
# 15   A01 Products of agriculture, hunting and relat...     0.000000
# ..                                                 ...          ...
# 73   A01 Products of agriculture, hunting and relat...   968.556164
# 14   A01 Products of agriculture, hunting and relat...  1233.082921
# 29   A01 Products of agriculture, hunting and relat...  1400.606436
# 58   A01 Products of agriculture, hunting and relat...  1718.292438
# 0    A01 Products of agriculture, hunting and relat...  3197.593647
#
#      proportion                     component  proportion_total
# 103    0.000000               Imported inputs          0.000000
# 18     0.000000  Domestically produced inputs          0.000000
# 17     0.000000  Domestically produced inputs          0.000000
# 16     0.000000  Domestically produced inputs          0.000000
# 15     0.000000  Domestically produced inputs          0.000000
# ..          ...                           ...               ...
# 73     0.063968  Domestically produced inputs          0.061422
# 14     0.081439  Domestically produced inputs          0.078197
# 29     0.092503  Domestically produced inputs          0.088821
# 58     0.113485  Domestically produced inputs          0.108967
# 0      0.211186  Domestically produced inputs          0.202778
#
# [208 rows x 7 columns]

# %%
data3.to_csv('../data/combined.csv')
